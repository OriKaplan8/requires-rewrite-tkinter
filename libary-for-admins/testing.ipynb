# %%
import RequireRewriteAnnotations as rr

# %%
rr.getBatchByAnnotatorNameAndBatchNumDataframe("Ori", 2)
# Out:
#    AnnotatorName                        DialogID  TurnNum  \
# 0     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        1
# 1     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        2
# 2     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        3
# 3     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        4
# 4     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        5
# 5     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        6
# 6     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        7
# 7     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        8
# 8     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0        9
# 9     Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0       10
# 10    Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0       11
# 11    Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0       12
# 12    Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0       13
# 13    Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0       14
# 14    Ori Kaplan  3a0ex8zrn8ovm41x482h1zvlof2by0       15
# ...

# %%
rr.getAllAnnotationsDataframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 rr.getAllAnnotationsDataframe()
#
# AttributeError: module 'RequireRewriteAnnotations' has no attribute 'getAllAnnotationsDataframe'
