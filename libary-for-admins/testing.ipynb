# %%
import RequireRewriteAnnotations as rr

# %%
rr.getAllAnnotationsDataframe()
# Out:
#    AnnotatorName                        DialogID  TurnNum  \
# 0     Ori Kaplan  3018q3zvoiqh6tkjkzarysii2vbarg        1
# 1     Ori Kaplan  3018q3zvoiqh6tkjkzarysii2vbarg        2
# 2     Ori Kaplan  3018q3zvoiqh6tkjkzarysii2vbarg        3
# 3     Ori Kaplan  3018q3zvoiqh6tkjkzarysii2vbarg        4
# 4     Ori Kaplan  3018q3zvoiqh6tkjkzarysii2vbarg        5
# ..           ...                             ...      ...
# 24          Afik  3quo65dnquoyop61ycae4yp7zexuoo        6
# 25          Afik  3quo65dnquoyop61ycae4yp7zexuoo        7
# 26          Afik  3quo65dnquoyop61ycae4yp7zexuoo        8
# 27          Afik  3quo65dnquoyop61ycae4yp7zexuoo        9
# 28          Afik  3quo65dnquoyop61ycae4yp7zexuoo       10
#
#                                            OgQuestion  RequiresRewrite
# 0                    Does he feel confident about it?                0
# 1                  What policy is he not in favor of?                0
# ...
