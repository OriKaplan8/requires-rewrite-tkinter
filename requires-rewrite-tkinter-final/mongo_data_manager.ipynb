# %% [markdown]
# # Initialization of MongoDB Connection
#
# This section of the code initializes the necessary Python libraries and sets up the connection to a MongoDB database. Below is an explanation of each component:
#
# ## Libraries Imported
#
# - **pymongo**: Used to work with MongoDB from Python. This library enables the creation of a client to interact with the database.
# - **datetime**: Provides classes for manipulating dates and times. It's used here to record timestamps when updating or inserting documents.
# - **json**: Supports JSON parsing. This module enables loading and parsing JSON data from files or strings.
#
# ## Database Connection
#
# - **Connection String**: A string that specifies the MongoDB server to connect to, including credentials and other connection options.
# - **Client Setup**: The `MongoClient` object is created using the connection string, which facilitates operations like inserting, retrieving, updating, and deleting documents.
# - **Database Selection**: Specifies the database (`require_rewrite_b`) from the MongoDB server to be used for operations.
#
# This setup is essential for performing any database operations that follow in the subsequent code.

# %%
#initlize eveything
from pymongo import MongoClient #mongo libary for the server
import datetime #for the time
import json #for the json files
connection_string = "mongodb+srv://orik:Ori121322@cluster0.tyiy3mk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0" #the connection string, the adress of the server 
client = MongoClient(connection_string)
db = client.require_rewrite_b #the name of the database

# %% [markdown]
# # Database Functions for JSON Data Management
#
# This document outlines various Python functions designed for managing JSON data in a MongoDB database. These functions enable adding, updating, retrieving, and deleting JSON templates and annotations.
#
# ## Functions
#
# ### `add_or_update_json_template_in_db`
#
# - **Purpose**: Adds or updates a JSON template in the MongoDB collection. These templates serve as the basis for annotations, which users can select and annotate.
# - **Parameters**:
#   - `project_name` (str): Name of the project.
#   - `file_id` (str): ID of the file.
#   - `json_data` (dict): JSON data to be added.
#   - `overwrite` (bool): If true, updates the document; otherwise, inserts new.
# - **Returns**: None.
#
# ### `retrieve_json_template_by_file_id`
#
# - **Purpose**: Retrieves the JSON template based on file ID from the MongoDB collection.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
# - **Returns**: JSON data as a dictionary.
#
# ### `retrieve_annotations_by_file_id`
#
# - **Purpose**: Retrieves all annotations for a given file ID. Initially, the JSON data in annotations contains fields set to null to indicate that they have not been annotated.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
# - **Returns**: A dictionary containing annotations, indexed by username. As users interact with the annotation software, fields that are annotated are updated with actual values.
#
# ### `retrieve_annotation_by_user_and_file_id`
#
# - **Purpose**: Retrieves the annotated file for a specific user and file ID. The annotations start with null values and are populated with data as the user performs annotations.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
#   - `username` (str): Username of the annotator.
# - **Returns**: JSON data of the annotated file, if found. Fields are initially set to null and updated as the user annotates them.
#
# ### `delete_json_template_and_annotations_by_file_id`
#
# - **Purpose**: Deletes a JSON template and all associated annotations based on file ID.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
# - **Returns**: None.
#
# ### `load_json_from_file`
#
# - **Purpose**: Loads JSON data from a file.
# - **Parameters**:
#   - `file_path` (str): Path to the JSON file.
# - **Returns**: JSON data as a dictionary.

# %%
def add_or_update_json_template_in_db(project_name, file_id, json_data, overwrite=False):
    """
    Adds a JSON template to the MongoDB collection.

    Parameters:
    - project_name (str): The name of the project.
    - file_id (str): The ID of the file.
    - json_data (dict): The JSON data to be added.
    - overwrite (bool): If True, the document will be updated if it exists. If False, the document will only be inserted if it doesn't exist.

    Returns:
    None
    """
    collection = db.json_batches
    query = {'file_id': file_id}

    if overwrite:
        # Update the document if it exists, or insert if it doesn't
        my_values = {"$set": {'file_id': file_id, 'json_data': json_data, 'project_name': project_name,
                              'annotated': False, 'uploaded': datetime.datetime.now()}}
    else:
        # Only set these fields if the document does not exist and is being inserted
        my_values = {"$setOnInsert": {'file_id': file_id, 'json_data': json_data, 'project_name': project_name,
                                      'annotated': False, 'uploaded': datetime.datetime.now()}}

    update_result = collection.update_one(query, my_values, upsert=True)
    
    if update_result.matched_count > 0:
        print(f"Document with file_id {file_id} updated.")
    elif update_result.upserted_id is not None:
        print(f"New document inserted with id {update_result.upserted_id}.")
    else:
        print("No changes made to the database.")
        
def retrieve_json_template_by_file_id(file_id):
    """
    Retrieves the JSON data from the MongoDB collection based on the specified file ID.

    Args:
        file_id (str): The ID of the file to retrieve the JSON data for.

    Returns:
        dict: The JSON data retrieved from the MongoDB collection.

    Raises:
        None

    """
    collection = db.json_batches
    query = {'file_id': file_id}
    result = collection.find(query)
    if result:
        print("Found document:")
        print(result['json_data'])  # Print only the json_data field
        return result['json_data']  # Return only the json_data field
    else:
        print("No document found with the specified project name and file ID.")
        return None

def retrieve_annotations_by_file_id(file_id):
    """
    Retrieves the annotated JSON data from the MongoDB collection based on the specified file ID.

    Args:
        file_id (str): The ID of the file to retrieve the annotated JSON data for.

    Returns:
        dict: The annotated JSON data retrieved from the MongoDB collection.

    Raises:
        None

    """
    collection = db.json_annotations
    query = {'file_id': file_id}
    result = collection.find(query)
    json_data = {}
    if result is not  None:
        for document in result:

            json_data[document["username"]] = document["json_data"]
                
     
        return json_data  # Return only the json_data field
    else:
        print("No document found with the specified project name and file ID.")
        return None
    
def retrieve_annotation_by_user_and_file_id(file_id, username):
    """
    Retrieves the annotated file of a specific annotator from the MongoDB collection.

    Parameters:
    - file_id (str): The ID of the file to retrieve.
    - username (str): The username of the annotator.

    Returns:
    - json_data (dict): The JSON data of the annotated file, if found.
    - None: If no document is found with the specified file ID or username.
    """

    collection = db.json_annotations
    query = {'file_id': file_id}
    result = collection.find_one(query)
    json_data = {}
    if result is not None:
        query = {'file_id': file_id, 'username': username}
        result = collection.find_one(query)
        if result is not None:
            json_data = result["json_data"]
            return json_data  # Return only the json_data field
        else: 
            print("No document found with the specified username.")
            return None
    else:
        print("No document found with the specified file ID.")
        return None
    
def delete_json_template_and_annotations_by_file_id(file_id):
    """
    Deletes a JSON template from the MongoDB collection based on the specified file ID.

    Args:
        file_id (str): The ID of the file to delete.

    Returns:
        None

    Raises:
        None

    """
    collection = db.json_batches
    query = {'file_id': file_id}
    result = collection.delete_one(query)
    if result.deleted_count > 0:
        print(f"Document with file_id {file_id} deleted.")

        collection = db.json_annotations
        query = {'file_id': file_id}
        result = collection.delete_many(query)
        print(f"Deleted {result.deleted_count} annotations for file_id {file_id}.")

    else:
        print("No document found with the specified file ID.")

def load_json_from_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %% [markdown]
# Example of retrieve_annotation_by_user_and_file_id:
#  - returns the annotated json file ori is currently annotating

# %%
retrieve_annotation_by_user_and_file_id("asi-14_4", "ori")
# Out:
# {'QReCC-Train_1102': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1102_1',
#     'original_question': 'Why did Gavin leave Titãs?',
#     'answer': 'Gavin stated that he was physically and mentally exhausted because of the Titas tours and album releases.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1102_2',
#     'original_question': 'Did they replace him with anyone?',
#     'answer': 'Yes, Drummer Mario Fabre, who has remained with the Titas since then as a session member.'}],
#   '1': {'sample_id': 'QReCC-Train_1102_2',
#    'requires_rewrite': 1,
#    'enough_context': 1}},
#  'QReCC-Train_7296': {'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7296_1',
#     'original_question': "What was Louison Bobet's personality like?",
#     'answer': 'The most striking feature of Louison Bobet was his ambition to behave like a Hollywood matinée idol, a sort of David Niven character in a dinner suit tuxedo.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7296_2',
#     'original_question': 'How was he a little moody?',
#     'answer': 'The British professional Brian Robinson called Louison Bobet a private man and a little moody and said he would sulk if things went wrong.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_7296_3',
#     'original_question': 'Did people not like him for his personality?',
#     'answer': "Géminiani says Bobet's diffident and elegant manner made him less popular even in his own Brittany than the more rustic, forthright manners of other Breton people such as Jean Robic."},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_7296_4',
#     'original_question': 'Who else had something to say about his personality?',
#     'answer': "French journalist René de Latour said of Louison Bobet in Sporting Cyclist that he didn't look good on a bike and that he had the legs of a football player."}],
#   '1': {'sample_id': 'QReCC-Train_7296_2',
#    'requires_rewrite': 1,
#    'enough_context': 0},
#   '2': {'sample_id': 'QReCC-Train_7296_3',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_7296_4',
#    'requires_rewrite': 0,
#    'enough_context': 1}},
#  'QReCC-Train_593': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_593_1',
#     'original_question': 'What songs did Max Martin produce with Cheiron and Denniz PoP?',
#     'answer': 'In 1993, Max Martin was hired by Cheiron Studios and spent time learning the basics, before the first production collaboration between PoP and Martin: Wish You Were Here in 1994.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_593_2',
#     'original_question': 'What artist sang Wish You Were Here?',
#     'answer': 'Rednex sang the song Wish You Were Here“'}],
#   '1': {'sample_id': 'QReCC-Train_593_2',
#    'requires_rewrite': 1,
#    'enough_context': 1}},
#  'QReCC-Train_2919': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2919_1',
#     'original_question': 'Did Bobby Jindal deliver the Republican response to February 2009 Barack Obama speech to joint session of Congress?',
#     'answer': "On February 24, 2009, Bobby Jindal delivered the official Republican response to President Obama's address to a joint session of Congress."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2919_2',
#     'original_question': 'Was the address extremely critical?',
#     'answer': 'President Obama discussed the recently passed $787 billion American Recovery and Reinvestment Act of 2009 as well as the Troubled Assets Relief Program, the state and future of the economy.'}],
#   '1': {'sample_id': 'QReCC-Train_2919_2',
#    'requires_rewrite': 0,
#    'enough_context': 1}},
#  'QReCC-Train_785': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_785_1',
#     'original_question': 'What was the most profitable fur at the beginning of the 18th century in the North American fur trade?',
#     'answer': 'At the beginning of the 18th century, more organized violence than in previous decades occurred between the Native Americans involved in the deerskin trade and white settlers.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_785_2',
#     'original_question': 'What happened as a result of the organized violence between Native Americans and white settlers?',
#     'answer': 'More organized violence than in previous decades occurred between the Native Americans involved in the deerskin trade and white settlers, most famously the Yamasee War.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_785_3',
#     'original_question': 'What impact did the Yamasee War and other fighting have on the fur trade?',
#     'answer': 'This uprising of Indians against fur traders almost wiped out the European colonists in the southeast.'}],
#   '1': {'sample_id': 'QReCC-Train_785_2',
#    'requires_rewrite': 1,
#    'enough_context': 0},
#   '2': {'sample_id': 'QReCC-Train_785_3',
#    'requires_rewrite': 0,
#    'enough_context': 1}},
#  'QReCC-Train_1981': {'number_of_turns': 8,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1981_1',
#     'original_question': 'When did Helen Reddy make a brief comeback?',
#     'answer': "In 2012, Reddy decided to return to performing after being buoyed by the warm reception she received when she sang at her sister's 80th birthday party."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1981_2',
#     'original_question': 'How many shows did she do after her comeback?',
#     'answer': "On 12 July 2012, Reddy returned to the musical stage at Croce's Jazz Bar and for a benefit concert for the arts at St. Genevieve High School"},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_1981_3',
#     'original_question': 'Did she do any other shows after St. Genevieve High School?',
#     'answer': 'Reddy performed at the Paramount nightclub at The Crown & Anchor in Provincetown on 13 October 2013.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_1981_4',
#     'original_question': 'Did she perform anywhere after that?',
#     'answer': 'She performed two nights at Catalina Supper Club, Los Angeles in November 2014, shortly after her 73rd birthday.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_1981_5',
#     'original_question': 'What did she sing at the Womens March?',
#     'answer': 'an a cappella version of her song, I Am Woman“'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_1981_6',
#     'original_question': 'Are there any other interesting aspects about this article?',
#     'answer': 'She maintains that she still refuses to sing Leave Me Alone (Ruby Red Dress)“'},
#    {'turn_num': 6,
#     'sample_id': 'QReCC-Train_1981_7',
#     'original_question': 'Why does she refuse to sing Leave Me Alone?',
#     'answer': 'she dislikes the monotony of the repeated chorus'},
#    {'turn_num': 7,
#     'sample_id': 'QReCC-Train_1981_8',
#     'original_question': 'Did she have any songs that she preferred to sing during her comeback?',
#     'answer': "She explained, One of the reasons that I'm coming back to singing is because I'm not doing the greatest hits. I'm doing the songs that I always loved.“"}],
#   '1': {'sample_id': 'QReCC-Train_1981_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_1981_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_1981_4',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': 'QReCC-Train_1981_5',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': 'QReCC-Train_1981_6',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': 'QReCC-Train_1981_7',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': 'QReCC-Train_1981_8',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_8996': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8996_1',
#     'original_question': 'where is the thymus gland in a cow',
#     'answer': 'Cows have more than one thymus, in their neck and by their heart.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8996_2',
#     'original_question': 'what is the purpose of the gland',
#     'answer': 'Within the thymus, T cells mature. T cells are critical to the adaptive immune system, where the body adapts specifically to foreign invaders.'}],
#   '1': {'sample_id': 'QReCC-Train_8996_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_4949': {'number_of_turns': 6,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4949_1',
#     'original_question': "Where were Ted DiBiase's accomplishments in 1983?",
#     'answer': 'Ted DiBiase entered All Japan Pro Wrestling (AJPW) in 1983. He won the NWA United National Championship on October 14, 1983.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4949_2',
#     'original_question': 'What more followed this victory?',
#     'answer': 'Three months later, on January 28, 1984, Ted DiBiase lost the title to Michael Hayes.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_4949_3',
#     'original_question': 'When did he fight again?',
#     'answer': 'In August 1985, Ted DiBiase formed a tag team with fellow gaijin Stan Hansen, and the two became the PWF Tag Team Champions.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_4949_4',
#     'original_question': "What was the highlight of this team's performance?",
#     'answer': "Later that year, Ted DiBiase and Stan Hansen entered the 1985 World's Strongest Tag Determination League and would emerge victorious, finishing in first place with 7 points."},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_4949_5',
#     'original_question': 'What happened in 1987?',
#     'answer': 'In August 1985, Ted DiBiase formed a tag team with fellow gaijin Stan Hansen, and the two became the PWF Tag Team Champions.'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_4949_6',
#     'original_question': 'What was significant about 1993?',
#     'answer': 'In September 1993, Ted DiBiase returned to AJPW and reformed his team with Stan Hansen.'}],
#   '1': {'sample_id': 'QReCC-Train_4949_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_4949_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_4949_4',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': 'QReCC-Train_4949_5',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': 'QReCC-Train_4949_6',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_9744': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_9744_1',
#     'original_question': 'lactic acid production would be the fate of which energy system',
#     'answer': 'the ultimate fate of the lactate is oxidation to ATP'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_9744_2',
#     'original_question': 'what does the energy system consist of',
#     'answer': 'As the name suggests the ATP-PC system consists of adenosine triphosphate and phosphocreatine.'}],
#   '1': {'sample_id': 'QReCC-Train_9744_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_6509': {'number_of_turns': 6,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6509_1',
#     'original_question': 'Where did Émilie du Châtelet go to school?',
#     'answer': "Du Châtelet's education has been the subject of much speculation, but nothing is known with certainty."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6509_2',
#     'original_question': 'Did she have a mentor or tutor?',
#     'answer': 'When she was small, her father arranged training for her in activities such as fencing and riding, and as she grew older, he brought tutors to the house for her.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_6509_3',
#     'original_question': 'Who else did she learn from?',
#     'answer': "Du Châtelet's father Louis-Nicolas, recognizing her early brilliance, arranged for Bernard Le Bovier de Fontenelle to visit and talk about astronomy with her when she was 10 years old."},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_6509_4',
#     'original_question': 'How did she get started in philosophy?',
#     'answer': 'In addition to producing famous translations of works by authors such as Bernard Mandeville and Isaac Newton, Du Châtelet wrote a number of significant philosophical essays, letters and books.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_6509_5',
#     'original_question': 'Any other famous philosophers she worked with?',
#     'answer': 'She had a well-known collaboration and romantic involvement with Voltaire.'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_6509_6',
#     'original_question': 'Did she ever attend a formal school?',
#     'answer': "Du Châtelet's education has been the subject of much speculation, but nothing is known with certainty."}],
#   '1': {'sample_id': 'QReCC-Train_6509_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_6509_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_6509_4',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': 'QReCC-Train_6509_5',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': 'QReCC-Train_6509_6',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_7254': {'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7254_1',
#     'original_question': 'who was chris gaines in relation to Garth Brooks',
#     'answer': 'Garth Brooks took on the alter ego of Chris Gaines, a fictitious rock and roll musician and character for an upcoming film titled The Lamb.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7254_2',
#     'original_question': 'did he release any music as Chris Gaines',
#     'answer': "In October 1999, the film's pre-release soundtrack, Garth Brooks in ... The Life of Chris Gaines, was released to much public criticism."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_7254_3',
#     'original_question': 'how did his fans feel about Gaines',
#     'answer': 'The majority of the American public was either bewildered, or completely unreceptive to the idea of Garth Brooks portraying a rock and roll musician.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_7254_4',
#     'original_question': 'Did he win any awards for work as Gaines',
#     'answer': 'Despite the less-than-spectacular response, Garth Brooks gained his first Billboard Top 40 pop single in Lost in You. The album was later certified Double Platinum by the RIAA.'}],
#   '1': {'sample_id': 'QReCC-Train_7254_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_7254_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_7254_4',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_10226': {'number_of_turns': 5,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_10226_1',
#     'original_question': 'what is the meaning of the name barbara',
#     'answer': 'Barbara is from the Greek barbaros meaning foreign or strange, traveler from a foreign land.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_10226_2',
#     'original_question': 'what about Matthew',
#     'answer': 'Matthew is a Greek form of the Hebrew name Mattityahu, meaning gift of YAHWEH.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_10226_3',
#     'original_question': 'what about Elizabeth',
#     'answer': 'Elizabeth is a feminine given name derived from a form of the Hebrew name Elisheva, meaning My God is an oath or My God is abundance.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_10226_4',
#     'original_question': 'how about Travis',
#     'answer': 'The meaning of the name Travis is crossing; crossroads; toll gate.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_10226_5',
#     'original_question': 'how about Justin',
#     'answer': 'Justin is an anglicized form of the Latin given name Justinus, a derivative of Justus, meaning just, fair, or righteous.'}],
#   '1': {'sample_id': 'QReCC-Train_10226_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_10226_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_10226_4',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': 'QReCC-Train_10226_5',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_10505': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_10505_1',
#     'original_question': 'who wrote the songs for beauty and the beast',
#     'answer': 'The 1991 soundtrack Beauty and the Beast: Original Motion Picture Soundtrack was written by composer Alan Menken and lyricist Howard Ashman.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_10505_2',
#     'original_question': 'what else has alan menken composed',
#     'answer': "Alan Menken's scores and songs for The Little Mermaid, Beauty and the Beast, Aladdin, and Pocahontas have each won him two Academy Awards."}],
#   '1': {'sample_id': 'QReCC-Train_10505_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_10224': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_10224_1',
#     'original_question': 'where did andrew carnegie write the gospel of wealth',
#     'answer': 'The Gospel of Wealth was published in the North American Review.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_10224_2',
#     'original_question': 'when was it written',
#     'answer': 'The Gospel of Wealth is an article written by Andrew Carnegie in June of 1889.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_10224_3',
#     'original_question': 'what was it about',
#     'answer': 'The Gospel of Wealth describes the responsibility of philanthropy by the new upper class of self-made rich.'}],
#   '1': {'sample_id': 'QReCC-Train_10224_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_10224_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_6740': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6740_1',
#     'original_question': 'What other activities did Paul Verhoeven do?',
#     'answer': 'Verhoeven is a member of the Jesus Seminar.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6740_2',
#     'original_question': 'What did he graduate with a degree in?',
#     'answer': 'Verhoeven graduated with a degree in mathematics and physics from the University of Leiden.'}],
#   '1': {'sample_id': 'QReCC-Train_6740_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_4521': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4521_1',
#     'original_question': 'When did Brooks & Dunn split up?',
#     'answer': 'On August 10, 2009, Brooks & Dunn announced that they would be splitting up after a tour titled The Last Rodeo.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4521_2',
#     'original_question': 'Did the band break up and if so, when?',
#     'answer': 'Brooks & Dunn performed their last concert together at the Bridgestone Arena in Nashville on September 2, 2010, with proceeds from the concert benefiting the Country Music Hall of Fame.'}],
#   '1': {'sample_id': 'QReCC-Train_4521_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_1207': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1207_1',
#     'original_question': 'How was Coolio associated to Tommy Boy Records?',
#     'answer': 'In 1994, Coolio signed to Tommy Boy Records'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1207_2',
#     'original_question': 'Why was he dropped from Tommy Boy Records?',
#     'answer': "Coolio's third solo album titled My Soul failed to reach the success of his previous two albums. Coolio was dropped from Tommy Boy Records."}],
#   '1': {'sample_id': 'QReCC-Train_1207_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_864': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_864_1',
#     'original_question': 'How did Will Forte get started in comedy?',
#     'answer': "Forte's first successful foray into comedy was 101 Things to Definitely Not Do If You Want to Get a Chick, a comic book he produced that details incompetent men."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_864_2',
#     'original_question': 'What was the comic book about?',
#     'answer': '101 Things to Definitely Not Do If You Want to Get a Chick is a comic book that details incompetent men.'}],
#   '1': {'sample_id': 'QReCC-Train_864_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_6131': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6131_1',
#     'original_question': 'How are Minit and Instant Records connected to Allen Toussaint?',
#     'answer': 'In 1960, Joe Banashak, of Minit Records and later Instant Records, hired Toussaint as an A&R man and record producer.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6131_2',
#     'original_question': 'What records did he produce?',
#     'answer': 'Southern Nights is a 1975 R&B concept album by Allen Toussaint.'}],
#   '1': {'sample_id': 'QReCC-Train_6131_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2907': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2907_1',
#     'original_question': 'What happened in 1999 with Jennifer Capriati?',
#     'answer': "1999 was Jennifer Capriati's best season in several years."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2907_2',
#     'original_question': 'Did she set any records?',
#     'answer': 'Jennifer Capriati set a number of youngest-ever records at the start of her career.'}],
#   '1': {'sample_id': 'QReCC-Train_2907_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_7917': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7917_1',
#     'original_question': 'who did announce a separate electorate for the dalits',
#     'answer': 'Dr Ambedkar had proposed the idea for a separate electorate for Dalits and untouchables in the first conference, which the Congress boycotted.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7917_2',
#     'original_question': "what were dr ambedkar's reasons",
#     'answer': 'Ambedkar felt that the system of unqualified joint electorates served the second purpose but it enabled the majority to influence the election of the representatives of the dalits community.'}],
#   '1': {'sample_id': 'QReCC-Train_7917_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_7329': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7329_1',
#     'original_question': "Who won the Women's single at Wimbledon 2019",
#     'answer': "Simona Halep defeated Serena Williams in the final, 6–2, 6–2 to win the Ladies' Singles tennis title at the 2019 Wimbledon Championships."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7329_2',
#     'original_question': 'how long was the match',
#     'answer': 'It took just 56 minutes for Simona Halep to secure victory where she committed only 3 unforced errors, the fewest on record in a Grand Slam final.'}],
#   '1': {'sample_id': 'QReCC-Train_7329_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_8943': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8943_1',
#     'original_question': 'who did marion bartoli beat in the wimbledon final',
#     'answer': "France's Marion Bartoli beat Sabine Lisicki in the Wimbledon final."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8943_2',
#     'original_question': 'what was the score',
#     'answer': 'Bartoli won her first Grand Slam title with a dominant 6-1 6-4 victory over Lisicki.'}],
#   '1': {'sample_id': 'QReCC-Train_8943_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_269': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_269_1',
#     'original_question': 'What happened in 2001 what did Dominik Hašek do?',
#     'answer': "In May 2001, Dominik Hašek founded the Dominik Hašek Youth Hockey League/Hašek's Heroes, and donated over $1 million to help underprivileged children in Buffalo play hockey."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_269_2',
#     'original_question': 'Did he set any records?',
#     'answer': 'Dominik Hašek set a record for shutouts in a postseason year.'}],
#   '1': {'sample_id': 'QReCC-Train_269_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_3071': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_3071_1',
#     'original_question': 'When did Brett Hull play with the the St. Louis Blues?',
#     'answer': 'March 7, 1988, Hull was traded, along with Steve Bozek, to the St. Louis Blues in exchange for defenseman Rob Ramage and goaltender Rick Wamsley.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_3071_2',
#     'original_question': 'How many goals did he make?',
#     'answer': 'His career total of 741 goals is the fourth highest in NHL history, and he is one of five players to score 50 goals in 50 games.'}],
#   '1': {'sample_id': 'QReCC-Train_3071_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_8044': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8044_1',
#     'original_question': 'where did the fish head song come from?',
#     'answer': 'Fish Heads is a novelty song by comedy rock duo Barnes & Barnes'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8044_2',
#     'original_question': 'when was the song released?',
#     'answer': 'released as a single in 1978 and later featured on their 1980 album Voobaha'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_8044_3',
#     'original_question': 'what is the song about?',
#     'answer': 'The song is about fish heads and all the things they are not able to do, such as answering questions, playing baseball, wearing sweaters, dancing, playing drums.'}],
#   '1': {'sample_id': 'QReCC-Train_8044_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_8044_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_5497': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_5497_1',
#     'original_question': "What is Chris Christie's stance on same sex marriage?",
#     'answer': 'Chris Christie indicated in 2009 that he would veto any bill legalizing same-sex marriage in the state.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_5497_2',
#     'original_question': 'Did he ever do that?',
#     'answer': 'On February 13, 2012, the State Senate passed a bill legalizing same-sex marriage.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_5497_3',
#     'original_question': 'Did he veto that bill?',
#     'answer': 'Governor Chris Christie vetoed the bill the next day.'}],
#   '1': {'sample_id': 'QReCC-Train_5497_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_5497_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_974': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_974_1',
#     'original_question': "what was Vaughn Meader's the first family?",
#     'answer': 'The First Family is a 1962 comedy album.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_974_2',
#     'original_question': 'Are there any other interesting aspects about this article?',
#     'answer': 'John F Kennedy himself was said to have given copies of the The first family album as Christmas gifts.'}],
#   '1': {'sample_id': 'QReCC-Train_974_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2902': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2902_1',
#     'original_question': "What is T-Pain's Thr33 Ringz?",
#     'answer': "Thr33 Ringz was T-Pain's third studio album."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2902_2',
#     'original_question': 'How did the album do?',
#     'answer': 'The album sold 168,000 records in its first week, reaching number four on the Billboard 200.'}],
#   '1': {'sample_id': 'QReCC-Train_2902_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_139': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_139_1',
#     'original_question': 'What is Leonardo from the teenage mutant ninja turtles personality?',
#     'answer': "He is the most skilled, the most serious, the most spiritual, the most disciplined, and the most in-line with Splinter's teachings and thoughts."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_139_2',
#     'original_question': 'Is Leonardo the leader?',
#     'answer': 'Leonardo is the eldest brother and the leader of the group'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_139_3',
#     'original_question': 'Is Leonardo a commanding leader?',
#     'answer': 'He is the one to usually take charge of the turtles when Master Splinter is not present.'}],
#   '1': {'sample_id': 'QReCC-Train_139_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_139_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2029': {'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2029_1',
#     'original_question': 'What did Ronald D. Moore do after Star Trek?',
#     'answer': 'After leaving Voyager, Moore briefly worked as a consulting producer on Good vs Evil'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2029_2',
#     'original_question': 'What did he work on after Star Trek was done?',
#     'answer': 'Roswell as a co-executive producer and staff writer.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_2029_3',
#     'original_question': 'Did he work on any other shows?',
#     'answer': 'In 2002, David Eick (whom Moore worked with on Good vs Evil) approached Moore about a new four-hour Battlestar Galactica mini-series for Universal.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_2029_4',
#     'original_question': 'What role did he play in the Battlestar Galactica mini-series?',
#     'answer': 'Moore developed the mini-series with Eick, writing the scripts, updating the old series, also developing a back-story that could work for a regular weekly series should the mini-series be successful.'}],
#   '1': {'sample_id': 'QReCC-Train_2029_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_2029_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_2029_4',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_1444': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1444_1',
#     'original_question': 'Who were Stark Naked?',
#     'answer': "Richard Darryl Way's new band, Stark Naked and the Car Thieves,"},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1444_2',
#     'original_question': 'Who were members of the Car Thieves?',
#     'answer': 'Darryl Way, Stewart Copeland, George Hatcher, Mick Jacques and Phil Kohn'}],
#   '1': {'sample_id': 'QReCC-Train_1444_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_6542': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6542_1',
#     'original_question': 'Are there any other interesting aspects about Boyz II Men?',
#     'answer': 'Boyz II Men (pronounced boys to men) is an American R&B and hip hop vocal group from Philadelphia, Pennsylvania, best known for emotional ballads and a cappella harmonies.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6542_2',
#     'original_question': 'What happen on the cruise',
#     'answer': "Boyz II Men headlined a Love Cruise from Miami, Florida, to Nassau, Bahamas in honor of their 20th anniversary and in observance of Valentine's Day."}],
#   '1': {'sample_id': 'QReCC-Train_6542_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_8851': {'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8851_1',
#     'original_question': 'who wrote the song just a closer walk with thee',
#     'answer': 'In 1940 Kenneth Morris arranged and published for the first time the well-known version of A Closer Walk With Thee.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8851_2',
#     'original_question': 'what does the song allude to',
#     'answer': 'The title and lyrics of the song allude to the Biblical passage from 2 Corinthians 5:7 which states, We walk by faith, not by sight and James 4:8.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_8851_3',
#     'original_question': 'what was the first recording',
#     'answer': 'The first known recording was by the Selah Jubilee Singers on October 8, 1941, New York City; with Thurman Ruth and John Ford lead vocal.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_8851_4',
#     'original_question': 'what is the second line of the song',
#     'answer': 'Just a closer walk with Thee, Grant it, Jesus, is my plea, Daily walking close to Thee, Let it be, dear Lord, let it be.'}],
#   '1': {'sample_id': 'QReCC-Train_8851_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_8851_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_8851_4',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2279': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2279_1',
#     'original_question': 'When did William Cullen go to the University of Edinburgh?',
#     'answer': 'In 1755 William Cullen become Professor of Chemistry and Medicine at the University of Edinburgh.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2279_2',
#     'original_question': 'Why did he go there?',
#     'answer': 'William Cullen was enticed by Lord Kames to become Professor of Chemistry and Medicine at the University of Edinburgh.'}],
#   '1': {'sample_id': 'QReCC-Train_2279_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_425': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_425_1',
#     'original_question': 'What is Caddoan Mississippian regarding Mississippian culture?',
#     'answer': 'The Caddoan Mississippian area is a regional variant of the Mississippian culture.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_425_2',
#     'original_question': 'What type of variant of the Mississippian culture?',
#     'answer': 'The climate in this area was drier than areas in the eastern woodlands, and the lower population on the plains may have meant fewer neighboring competing chiefdoms to contend with.'}],
#   '1': {'sample_id': 'QReCC-Train_425_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_4736': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4736_1',
#     'original_question': 'Why was Vladimir Nabokov in Berlin?',
#     'answer': "In 1920, Nabokov's family moved to Berlin, where his father set up the émigré newspaper Rul' (Rudder). Nabokov followed them to Berlin two years later, after completing studies at Cambridge."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4736_2',
#     'original_question': 'What happened after that',
#     'answer': 'Nabokov had become a recognised poet and writer within the émigré community and published under the nom de plume V. Sirin.'}],
#   '1': {'sample_id': 'QReCC-Train_4736_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2290': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2290_1',
#     'original_question': "What was unique about Lawrence Alma-Tadema's style?",
#     'answer': "Lawrence Alma-Tadema's works are remarkable for the way in which flowers, textures and hard reflecting substances, like metals, pottery, and especially marble, are painted."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2290_2',
#     'original_question': 'Was there anything else unique?',
#     'answer': 'Lawrence Alma-Tadema was a perfectionist. He worked assiduously to make the most of his paintings, often repeatedly reworking parts of paintings before becoming satisfied by his own high standards.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_2290_3',
#     'original_question': 'Who were his influences?',
#     'answer': 'By 1871 Lawrence Alma-Tadema met and befriended most of the major Pre-Raphaelite painters and it was in part due to their influence that shows in his style.'}],
#   '1': {'sample_id': 'QReCC-Train_2290_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_2290_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_3034': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_3034_1',
#     'original_question': 'When was Gentle Giant originally formed?',
#     'answer': 'Gentle Giant was formed in 1969 when the Shulman brothers teamed up with two other multi-instrumentalists, Gary Green and Kerry Minnear, plus drummer Martin Smith'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_3034_2',
#     'original_question': 'What did the brothers play?',
#     'answer': 'The Shulman brothers, meanwhile, settled into typically multi-instrumental roles of their own - Derek on saxophone and recorder, Ray on bass and violin and Phil on saxophone, trumpet, and clarinet'}],
#   '1': {'sample_id': 'QReCC-Train_3034_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_4544': {'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4544_1',
#     'original_question': 'What role did Pierrot play in Shakespeare at the Funambules?',
#     'answer': 'Pierrot murders an old-clothes man for garments to court a duchess.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4544_2',
#     'original_question': 'Is he punished for the murder?',
#     'answer': "Pierrot is then skewered in turn by the sword with which he stabbed the old-clothes man when the latter's ghost lures him into a dance at his wedding."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_4544_3',
#     'original_question': 'Why did Pierrot commit the murder?',
#     'answer': 'Pierrot murders an old-clothes man for garments to court a duchess.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_4544_4',
#     'original_question': "What happens once he's lured into a dance at the wedding?",
#     'answer': "Pierrot is then skewered in turn by the sword with which he stabbed the old-clothes man when the latter's ghost lures him into a dance at his wedding."}],
#   '1': {'sample_id': 'QReCC-Train_4544_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_4544_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_4544_4',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_6170': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6170_1',
#     'original_question': 'Who are the current band members of Fairport Convention',
#     'answer': 'Simon Nicol, Dave Pegg, Ric Sanders, Chris Leslie, and Gerry Conway'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6170_2',
#     'original_question': 'Have they won any awards recently',
#     'answer': 'At the 2007 BBC Radio 2 Folk Awards Fairport Convention received an award recognising the band for ‘Favourite Folk Track Of All Time’ for Who Knows Where the Time Goes?.'}],
#   '1': {'sample_id': 'QReCC-Train_6170_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2654': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2654_1',
#     'original_question': 'Were there any rule changes for the Veterans Committee in 2008?',
#     'answer': 'Voting on the managers/umpires and executives ballots will now be conducted for induction in even-numbered years, starting with the class of 2008.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2654_2',
#     'original_question': 'How were those changes made?',
#     'answer': 'The voting body for the managers/umpires ballot will be a sixteen-member body of Hall of Famers.'}],
#   '1': {'sample_id': 'QReCC-Train_2654_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_5866': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_5866_1',
#     'original_question': 'What did Terry Gilliam do in the movie Monty Python?',
#     'answer': "Terry Gilliam was a part of Monty Python's Flying Circus from its outset, credited at first as an animator and later as a full member."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_5866_2',
#     'original_question': 'what did he animate?',
#     'answer': "Terry Gilliam's animations mix his own art, characterized by soft gradients and odd, bulbous shapes, with backgrounds and moving cutouts from antique photographs, mostly from the Victorian era."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_5866_3',
#     'original_question': 'Who else was involved in Monty Python?',
#     'answer': 'Monty Python’s Flying Circus consisted of Graham Chapman, John Cleese, Eric Idle, Terry Jones, Michael Palin and Terry Gilliam, aka the Pythons.'}],
#   '1': {'sample_id': 'QReCC-Train_5866_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_5866_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_9446': {'number_of_turns': 5,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_9446_1',
#     'original_question': 'what is the job of a motor neuron',
#     'answer': 'A single motor neuron may innervate many muscle fibres and a muscle fibre can undergo many action potentials in the time taken for a single muscle twitch.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_9446_2',
#     'original_question': 'where is the neuron located',
#     'answer': 'A motor neuron is a neuron whose cell body is located in the motor cortex, brainstem or the spinal cord.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_9446_3',
#     'original_question': 'what types are there',
#     'answer': 'There are two types of motor neuron – upper motor neurons and lower motor neurons.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_9446_4',
#     'original_question': 'what is an upper',
#     'answer': 'Upper motor neurons are found in the cerebral cortex and brainstem and carry information down to activate interneurons and lower motor neurons, which in turn directly signal muscles.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_9446_5',
#     'original_question': 'what is a lower',
#     'answer': 'Lower motor neurons are motor neurons located in either the anterior grey column, anterior nerve roots or the cranial nerve nuclei of the brainstem and cranial nerves with motor function.'}],
#   '1': {'sample_id': 'QReCC-Train_9446_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_9446_3',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': 'QReCC-Train_9446_4',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': 'QReCC-Train_9446_5',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_796': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_796_1',
#     'original_question': "What were some of Joe Biden's early senate activities?",
#     'answer': 'During his first years in the Senate, Joe Biden focused on legislation regarding consumer-protection and environmental issues and called for greater accountability on the part of government.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_796_2',
#     'original_question': 'Was he successful in this?',
#     'answer': 'In mid-1974, freshman Senator Joe Biden was named one of the 200 Faces for the Future by Time magazine.'}],
#   '1': {'sample_id': 'QReCC-Train_796_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_10494': {'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_10494_1',
#     'original_question': 'who is the voice of the arbys commercials',
#     'answer': "Since 2015 Ving Rhames's deep voice has provided the narration for numerous Arby's commercials, with the catchline Arby's, we have the meats!“"},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_10494_2',
#     'original_question': 'what kind of meats',
#     'answer': "There are currently four different types of beef that can be enjoyed at Arby's including: roast beef, corned beef, brisket and USDA Choice top round Angus steak."}],
#   '1': {'sample_id': 'QReCC-Train_10494_2',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  'QReCC-Train_2598': {'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2598_1',
#     'original_question': 'What was the Chautauqua circuit for William Jennings Bryan?',
#     'answer': 'After the election, Bryan returned to journalism and oratory, frequently appearing on the Chautauqua circuits.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2598_2',
#     'original_question': 'What are some examples of the topics that he spoke about?',
#     'answer': 'he spoke on virtue and spirituality, and educated audiences about political issues.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_2598_3',
#     'original_question': 'What is another topic that he spoke on?',
#     'answer': 'In the same “The Prince of Peace” speech, Bryan stressed the importance of public service–a sentiment which reflected the core principles of the Chautauqua movement.'}],
#   '1': {'sample_id': 'QReCC-Train_2598_2',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': 'QReCC-Train_2598_3',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  '3kms4qqvk2qqfgow5vnmbh7v4ssfkl': {'number_of_turns': 15,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '3kms4qqvk2qqfgow5vnmbh7v4ssfkl-1-0',
#     'original_question': 'What was she wanting?',
#     'answer': 'Shelly wanted a puppy'},
#    {'turn_num': 1,
#     'sample_id': '3kms4qqvk2qqfgow5vnmbh7v4ssfkl-2-0',
#     'original_question': 'Who was she asking for one?',
#     'answer': 'She asked her mommy and daddy'},
#    {'turn_num': 2,
#     'sample_id': '3kms4qqvk2qqfgow5vnmbh7v4ssfkl-3-0',
#     'original_question': 'and how often was she asking them for it?',
#     'answer': 'every day'},
#    {'turn_num': 3,
# ...
#   '1': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '3yw4xosqkqldsxz0sac3s2cz50bu1i-9-0',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  '31qnsg6a5rtt5m7pens7xklnbvt87n': {'number_of_turns': 10,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-1-0',
#     'original_question': 'Who was he showing around?',
#     'answer': 'a foreign visitor'},
#    {'turn_num': 1,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-2-0',
#     'original_question': 'who was showing the visitor around?',
#     'answer': 'An Englishman'},
#    {'turn_num': 2,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-3-0',
#     'original_question': 'where was he showing them around?',
#     'answer': 'London'},
#    {'turn_num': 3,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-4-0',
#     'original_question': 'Was the visitor a man or a woman?',
#     'answer': 'Then he said'},
#    {'turn_num': 4,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-5-0',
#     'original_question': 'did the englishman get angry',
#     'answer': 'Englishman got angry'},
#    {'turn_num': 5,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-6-0',
#     'original_question': 'how many days did the visitor say his countrymen could finish the cathedral?',
#     'answer': 'forty days'},
#    {'turn_num': 6,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-7-0',
#     'original_question': 'How long did it take the English?',
#     'answer': 'Near forty years'},
#    {'turn_num': 7,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-8-0',
#     'original_question': 'How long did it take for the tower of london?',
#     'answer': 'About 500 years'},
#    {'turn_num': 8,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-9-0',
#     'original_question': 'how long did the visitor say it would take?',
#     'answer': 'five months'},
#    {'turn_num': 9,
#     'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-10-0',
#     'original_question': "Did they go to St.Mark's cathedral?",
#     'answer': "St. Paul's"}],
#   '1': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '31qnsg6a5rtt5m7pens7xklnbvt87n-10-0',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  '3of2m9aatgowkxfw67hte9ndgvdkz1': {'number_of_turns': 15,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-1-0',
#     'original_question': 'Who was ralph?',
#     'answer': 'Ralph was an alligator'},
#    {'turn_num': 1,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-2-0',
#     'original_question': 'How many brothers did he have?',
#     'answer': 'Ralph had three brothers'},
#    {'turn_num': 2,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-3-0',
#     'original_question': 'What were their names?',
#     'answer': 'Henry, Larry, and Thomas.'},
#    {'turn_num': 3,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-4-0',
#     'original_question': 'Did they like the water?',
#     'answer': "But none of Ralph's three brothers liked to play in the water"},
#    {'turn_num': 4,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-5-0',
#     'original_question': 'Who would chase Ralph?',
#     'answer': 'Henry'},
#    {'turn_num': 5,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-6-0',
#     'original_question': 'Why?',
#     'answer': 'but the meanest of them all was Henry'},
#    {'turn_num': 6,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-7-0',
#     'original_question': 'Were they all mean?',
#     'answer': 'They were very mean brothers,'},
#    {'turn_num': 7,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-8-0',
#     'original_question': 'did Henry do anything about it?',
#     'answer': 'Ralph thought of a great idea.'},
#    {'turn_num': 8,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-9-0',
#     'original_question': 'What did Ralph do?',
#     'answer': 'trick Henry into thinking one side of the lake was scary.'},
#    {'turn_num': 9,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-10-0',
#     'original_question': 'how?',
#     'answer': 'Ralph dressed up in a spooky costume and waited for Henry to swim over to the side of the lake.'},
#    {'turn_num': 10,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-11-0',
#     'original_question': 'and then?',
#     'answer': 'started making spooky sounds and scared Henry back to the other side of the lake.'},
#    {'turn_num': 11,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-12-0',
#     'original_question': 'What did henry do?',
#     'answer': 'Henry back to the other side of the lake.'},
#    {'turn_num': 12,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-13-0',
#     'original_question': 'did he ever come back?',
#     'answer': 'Henry was so scared he never came to the other side of the lake again'},
#    {'turn_num': 13,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-14-0',
#     'original_question': 'How did ralph feel then?',
#     'answer': 'free to splash around in peace.'},
#    {'turn_num': 14,
#     'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-15-0',
#     'original_question': 'did he enjoy splashing around?',
#     'answer': 'Ralph was an alligator that loved to splash around in the water.'}],
#   '1': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-10-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '10': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-11-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '11': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-12-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '12': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-13-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '13': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-14-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '14': {'sample_id': '3of2m9aatgowkxfw67hte9ndgvdkz1-15-0',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  '32xvdsjfpzx14acn2clv6b5aksj2ms': {'number_of_turns': 12,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-1-0',
#     'original_question': 'what color chair did Angie sit in?',
#     'answer': 'Angie sat in a brown chair'},
#    {'turn_num': 1,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-2-0',
#     'original_question': 'was she drawing?',
#     'answer': 'She made a drawing of her mother.'},
#    {'turn_num': 2,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-3-0',
#     'original_question': 'what did she draw?',
#     'answer': '. She made a drawing of her mother.'},
#    {'turn_num': 3,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-4-0',
#     'original_question': 'what did her mother find?',
#     'answer': 'Her mother found the book.'},
#    {'turn_num': 4,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-5-0',
#     'original_question': 'what color was it?',
#     'answer': 'It was a green book.'},
#    {'turn_num': 5,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-6-0',
#     'original_question': 'what section did they go to?',
#     'answer': 'Then they went to the Mystery section.'},
#    {'turn_num': 6,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-7-0',
#     'original_question': 'did Angie sit in a different chair?',
#     'answer': 'After the story Angie sat in the red chair'},
#    {'turn_num': 7,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-8-0',
#     'original_question': 'what color was it?',
#     'answer': 'Angie sat in the red chair'},
#    {'turn_num': 8,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-9-0',
#     'original_question': 'who did she draw this time?',
#     'answer': 'Angie drew a picture of her best friend Lilly.'},
#    {'turn_num': 9,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-10-0',
#     'original_question': 'did Angie sit in a blue chair?',
#     'answer': 'Angie sat in the red chair'},
#    {'turn_num': 10,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-11-0',
#     'original_question': 'did she draw a picture of her brother?',
#     'answer': 'Angie drew a picture of her best friend Lilly.'},
#    {'turn_num': 11,
#     'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-12-0',
#     'original_question': 'where did miss hudson hang the picture?',
#     'answer': 'Miss Hudson hung the pictures on the wall.'}],
#   '1': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-10-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '10': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-11-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '11': {'sample_id': '32xvdsjfpzx14acn2clv6b5aksj2ms-12-0',
#    'requires_rewrite': None,
#    'enough_context': None}},
#  '3befod78w6tb7ora6q4jzq28577m43': {'number_of_turns': 13,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-1-0',
#     'original_question': 'What kind of health problems has he been having?',
#     'answer': 'stroke'},
#    {'turn_num': 1,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-2-0',
#     'original_question': 'Who did he name to the top military board?',
#     'answer': 'his brother-in-law'},
#    {'turn_num': 2,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-3-0',
#     'original_question': 'What is his name?',
#     'answer': 'Jang Song Thaek'},
#    {'turn_num': 3,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-4-0',
#     'original_question': 'Who does he consider to be his right hand man?',
#     'answer': 'Jang Song Thaek'},
#    {'turn_num': 4,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-5-0',
#     'original_question': "How long has Jang been married to Kim's sister?",
#     'answer': 'since 1972'},
#    {'turn_num': 5,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-6-0',
#     'original_question': 'What is Jang',
#     'answer': "a director of the Workers' Party"},
#    {'turn_num': 6,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-7-0',
#     'original_question': 'Were there any changes to the parliament?',
#     'answer': 'no other major changes in the new parliament'},
#    {'turn_num': 7,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-8-0',
#     'original_question': 'How many people did he increase the agency with?',
#     'answer': 'Kim also increased the number of members in the military agency to 13, from eight'},
#    {'turn_num': 8,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-9-0',
#     'original_question': 'How active is Kim in public functions?',
#     'answer': 'long absence from public functions'},
#    {'turn_num': 9,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-10-0',
#     'original_question': 'What do people speculate that he is getting ready to do?',
#     'answer': 'someone to take over from him'},
#    {'turn_num': 10,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-11-0',
#     'original_question': 'What do analysts say paves a way for an heir?',
#     'answer': 'added his brother-in-law to a military board'},
#    {'turn_num': 11,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-12-0',
#     'original_question': 'What was Kim reappointed as?',
#     'answer': 'chairman of the military board'},
#    {'turn_num': 12,
#     'sample_id': '3befod78w6tb7ora6q4jzq28577m43-13-0',
#     'original_question': 'What did Kim Ho-nyoun tell Yonhap in a briefing?',
#     'answer': 'Overall, the power of the National Defense Commission was strengthened'}],
#   '1': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-10-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '10': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-11-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '11': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-12-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '12': {'sample_id': '3befod78w6tb7ora6q4jzq28577m43-13-0',
#    'requires_rewrite': None,
#    'enough_context': None}}}
